# %% [markdown]
# ## Pizza Sales Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import os

# %%
# create path to csvs
path = 'pizza_store_tables'

# %%
csv_list = os.listdir(path)
csv_list
# Out:
# ['.ipynb_checkpoints',
#  'orders.csv',
#  'order_details - Copy.csv',
#  'order_details.csv',
#  'pizzas.csv',
#  'pizza_types - Copy.csv',
#  'pizza_types.csv']

# %% [markdown]
# ### Orders Table EDA
# - Check data types
# - Check for null values
# - Check for duplicates in columns that should have unique values

# %%
# read in orders table
order_path = os.path.join(path,'orders.csv')
order_path
orders_df = pd.read_csv(order_path)
orders_df.head()
# Out:
#    order_id        date      time
# 0         1  2015-01-01  11:38:36
# 1         2  2015-01-01  11:57:40
# 2         3  2015-01-01  12:12:28
# 3         4  2015-01-01  12:16:31
# 4         5  2015-01-01  12:21:30

# %% [markdown]
# #### Check data types and for null values

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21350 entries, 0 to 21349
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  21350 non-null  int64
#  1   date      21350 non-null  object
#  2   time      21350 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 500.5+ KB

# %% [markdown]
# No nulls, order_id is int64 data type as expected.
# Date and time are objects, may need to be converted to datetime for further analysis.

# %% [markdown]
# #### Check for duplicates in the order_id column

# %%
orders_df['order_id'].nunique()
# Out:
# 21350

# %% [markdown]
# No duplicates

# %% [markdown]
# ### Order Details table EDA
#     Perform similar checks as with above table

# %%
# read in order_details table
order_details_path = os.path.join(path,'order_details.csv')
order_details_df = pd.read_csv(order_details_path)
order_details_df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity
# 0                 1         1     hawaiian_m         1
# 1                 2         2  classic_dlx_m         1
# 2                 3         2  five_cheese_l         1
# 3                 4         2    ital_supr_l         1
# 4                 5         2     mexicana_m         1

# %%
order_details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# No null values

# %%
order_details_df.nunique()
# Out:
# order_details_id    48620
# order_id            21350
# pizza_id               91
# quantity                4
# dtype: int64

# %% [markdown]
# #### Results:
#     order_details_id: no duplicates, this is the primary key for this table
#     order_id:21350 unique values corresponds correctly to order_id of orders table; this is foreign key
#     pizza_id: 91 unique values, when checking pizzas table, should not be fewer than 91 pizza_ids in that table

# %% [markdown]
# #### Check min and max order quantities to ensure no odd results such as negative units ordered

# %%
order_details_df['quantity'].max()
# Out:
# 4

# %%
order_details_df['quantity'].min()
# Out:
# 1

# %% [markdown]
# ### Pizzas table EDA

# %%
# read in pizzas csv
pizzas_path = os.path.join(path,'pizzas.csv')
pizzas_df = pd.read_csv(pizzas_path)
pizzas_df.head()
# Out:
#      pizza_id pizza_type_id size  price
# 0   bbq_ckn_s       bbq_ckn    S  12.75
# 1   bbq_ckn_m       bbq_ckn    M  16.75
# 2   bbq_ckn_l       bbq_ckn    L  20.75
# 3  cali_ckn_s      cali_ckn    S  12.75
# 4  cali_ckn_m      cali_ckn    M  16.75

# %% [markdown]
# There are separate fields pizza_id and pizza_type_id, where pizza_id is a combination of pizza_type and size, so there should be far more pizza_ids than pizza_type_ids

# %%
pizzas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_id       96 non-null     object
#  1   pizza_type_id  96 non-null     object
#  2   size           96 non-null     object
#  3   price          96 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 3.1+ KB

# %% [markdown]
# No null values, price is float64 as expected

# %%
pizzas_df.describe()
# Out:
#            price
# count  96.000000
# mean   16.440625
# std     4.090266
# min     9.750000
# 25%    12.500000
# 50%    16.250000
# 75%    20.250000
# max    35.950000

# %%
pizzas_df['pizza_id'].nunique()
# Out:
# 96

# %% [markdown]
# There 96 unique pizza_ids, which validates the 91 from the order_details_table, and 5 pizza_ids have not been ordered in the year

# %%
pizzas_df['pizza_type_id'].nunique()
# Out:
# 32

# %% [markdown]
# There are 32 unique pizza_type_ids, so should not be fewer than 32 in the pizza_types_table

# %% [markdown]
# ### Pizza Types Eda

# %%
pizza_types_df = pd.read_csv(os.path.join(path,'pizza_types.csv'),encoding= 'unicode_escape')
pizza_types_df.head()
# Out:
#   pizza_type_id                          name category  \
# 0       bbq_ckn    The Barbecue Chicken Pizza  Chicken
# 1      cali_ckn  The California Chicken Pizza  Chicken
# 2   ckn_alfredo     The Chicken Alfredo Pizza  Chicken
# 3     ckn_pesto       The Chicken Pesto Pizza  Chicken
# 4    southw_ckn   The Southwest Chicken Pizza  Chicken
#
#                                          ingredients
# 0  Barbecued Chicken, Red Peppers, Green Peppers,...
# 1  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# 2  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 3  Chicken, Tomatoes, Red Peppers, Spinach, Garli...
# 4  Chicken, Tomatoes, Red Peppers, Red Onions, Ja...

# %%
pizza_types_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_type_id  32 non-null     object
#  1   name           32 non-null     object
#  2   category       32 non-null     object
#  3   ingredients    32 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# No values

# %%
pizza_types_df.nunique()
# Out:
# pizza_type_id    32
# name             32
# category          4
# ingredients      32
# dtype: int64

# %% [markdown]
# There are 32 unique pizza_type_ids with no duplicates, which validates the 32 from the pizzas table. There are 32 unique sets of ingredients, which confirms there are no duplicated ingredient sets for the 32 pizza types.

# %% [markdown]
# ### Analysis and Dashboard Data Validation

# %%
# combine date and time object fields and convert to date time
orders_df['order_date'] = orders_df['date'] + ' ' + orders_df['time']
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'])
orders_df.head()
# Out:
#    order_id        date      time          order_date
# 0         1  2015-01-01  11:38:36 2015-01-01 11:38:36
# 1         2  2015-01-01  11:57:40 2015-01-01 11:57:40
# 2         3  2015-01-01  12:12:28 2015-01-01 12:12:28
# 3         4  2015-01-01  12:16:31 2015-01-01 12:16:31
# 4         5  2015-01-01  12:21:30 2015-01-01 12:21:30

# %%
print(orders_df['date'].min(),orders_df['date'].max())
# Out:
# 2015-01-01 2015-12-31

# %%
print(orders_df['time'].min(),orders_df['time'].max())
# Out:
# 09:52:21 23:05:52

# %% [markdown]
# The dashboard should not

# %%
# get sales $ for each month
orders_df2 = pd.merge(left=orders_df,right=order_details_df,how='inner',on='order_id')
orders_df2.head()
# Out:
#    order_id        date      time          order_date  order_details_id  \
# 0         1  2015-01-01  11:38:36 2015-01-01 11:38:36                 1
# 1         2  2015-01-01  11:57:40 2015-01-01 11:57:40                 2
# 2         2  2015-01-01  11:57:40 2015-01-01 11:57:40                 3
# 3         2  2015-01-01  11:57:40 2015-01-01 11:57:40                 4
# 4         2  2015-01-01  11:57:40 2015-01-01 11:57:40                 5
#
#         pizza_id  quantity
# 0     hawaiian_m         1
# 1  classic_dlx_m         1
# 2  five_cheese_l         1
# 3    ital_supr_l         1
# 4     mexicana_m         1

# %%
line_item_df = pd.merge(left=orders_df2,right=pizzas_df,how='inner',on='pizza_id')
line_item_df.head()
# Out:
#    order_id        date      time          order_date  order_details_id  \
# 0         1  2015-01-01  11:38:36 2015-01-01 11:38:36                 1
# 1        77  2015-01-02  12:22:46 2015-01-02 12:22:46               179
# 2       146  2015-01-03  14:22:10 2015-01-03 14:22:10               357
# 3       163  2015-01-03  16:54:54 2015-01-03 16:54:54               389
# 4       247  2015-01-04  20:55:29 2015-01-04 20:55:29               568
#
#      pizza_id  quantity pizza_type_id size  price
# 0  hawaiian_m         1      hawaiian    M  13.25
# 1  hawaiian_m         1      hawaiian    M  13.25
# 2  hawaiian_m         1      hawaiian    M  13.25
# 3  hawaiian_m         1      hawaiian    M  13.25
# 4  hawaiian_m         1      hawaiian    M  13.25

# %%
line_item_df['line_cost']=line_item_df['quantity'] * line_item_df['price']
line_item_df.head()
# Out:
#    order_id        date      time          order_date  order_details_id  \
# 0         1  2015-01-01  11:38:36 2015-01-01 11:38:36                 1
# 1        77  2015-01-02  12:22:46 2015-01-02 12:22:46               179
# 2       146  2015-01-03  14:22:10 2015-01-03 14:22:10               357
# 3       163  2015-01-03  16:54:54 2015-01-03 16:54:54               389
# 4       247  2015-01-04  20:55:29 2015-01-04 20:55:29               568
#
#      pizza_id  quantity pizza_type_id size  price  line_cost
# 0  hawaiian_m         1      hawaiian    M  13.25      13.25
# 1  hawaiian_m         1      hawaiian    M  13.25      13.25
# 2  hawaiian_m         1      hawaiian    M  13.25      13.25
# 3  hawaiian_m         1      hawaiian    M  13.25      13.25
# 4  hawaiian_m         1      hawaiian    M  13.25      13.25

# %%
order_df3 = line_item_df.groupby(['order_id']).agg({'order_date':'max','quantity':'sum','line_cost':'sum'}).reset_index()
order_df3.head()
# Out:
#    order_id          order_date  quantity  line_cost
# 0         1 2015-01-01 11:38:36         1      13.25
# 1         2 2015-01-01 11:57:40         5      92.00
# 2         3 2015-01-01 12:12:28         2      37.25
# 3         4 2015-01-01 12:16:31         1      16.50
# 4         5 2015-01-01 12:21:30         1      16.50

# %%
monthly_sales_df = order_df3.resample('M',on='order_date').agg({'order_id':'count','quantity':'sum','line_cost':'sum'})
monthly_sales_df
# Out:
#             order_id  quantity  line_cost
# order_date
# 2015-01-31      1845      4232   69793.30
# 2015-02-28      1685      3961   65159.60
# 2015-03-31      1840      4261   70397.10
# 2015-04-30      1799      4151   68736.80
# 2015-05-31      1853      4328   71402.75
# 2015-06-30      1773      4107   68230.20
# 2015-07-31      1935      4392   72557.90
# 2015-08-31      1841      4168   68278.25
# 2015-09-30      1661      3890   64180.05
# 2015-10-31      1646      3883   64027.60
# 2015-11-30      1792      4266   70395.35
# 2015-12-31      1680      3935   64701.15

# %%
december_line_item_df = line_item_df[line_item_df['date']>'2015-11-30']
december_line_item_df.head()
# Out:
#      order_id        date      time          order_date  order_details_id  \
# 430     19680  2015-12-01  12:24:32 2015-12-01 12:24:32             44786
# 431     19690  2015-12-01  13:24:16 2015-12-01 13:24:16             44803
# 432     19704  2015-12-01  16:22:17 2015-12-01 16:22:17             44838
# 433     19712  2015-12-01  17:45:53 2015-12-01 17:45:53             44853
# 434     19722  2015-12-01  19:21:05 2015-12-01 19:21:05             44875
#
#        pizza_id  quantity pizza_type_id size  price  line_cost
# 430  hawaiian_m         1      hawaiian    M  13.25      13.25
# 431  hawaiian_m         1      hawaiian    M  13.25      13.25
# 432  hawaiian_m         1      hawaiian    M  13.25      13.25
# 433  hawaiian_m         1      hawaiian    M  13.25      13.25
# 434  hawaiian_m         1      hawaiian    M  13.25      13.25

# %%
december_line_item_df['quantity'].sum()
# Out:
# 3935

# %%
december_line_item_df['line_cost'].sum()
# Out:
# 64701.149999999994

# %%
december_line_item_df.describe()
# Out:
#            order_id  order_details_id     quantity        price    line_cost
# count   3859.000000       3859.000000  3859.000000  3859.000000  3859.000000
# mean   20511.754859      46691.000000     1.019694    16.442083    16.766300
# std      490.732223       1114.141673     0.140818     3.579850     4.360662
# min    19671.000000      44762.000000     1.000000     9.750000     9.750000
# 25%    20073.500000      45726.500000     1.000000    12.500000    12.750000
# 50%    20505.000000      46691.000000     1.000000    16.500000    16.500000
# 75%    20943.500000      47655.500000     1.000000    20.250000    20.500000
# max    21350.000000      48620.000000     3.000000    35.950000    51.000000

# %%
print(december_line_item_df.time.max(),december_line_item_df.time.min())
# Out:
# 23:03:23 11:02:20

# %%
december_line_item_df.resample('60min',on='order_date').agg({'order_id':'count','quantity':'sum','line_cost':'sum'})
# Out:
#                      order_id  quantity  line_cost
# order_date
# 2015-12-01 11:00:00        11        11     163.75
# 2015-12-01 12:00:00        23        24     396.60
# 2015-12-01 13:00:00        26        26     410.25
# 2015-12-01 14:00:00         6         6     103.50
# 2015-12-01 15:00:00         7         7      98.70
# ...                       ...       ...        ...
# 2015-12-31 19:00:00        22        23     396.15
# 2015-12-31 20:00:00        16        17     278.50
# 2015-12-31 21:00:00         7         7     113.20
# 2015-12-31 22:00:00         1         1      20.25
# 2015-12-31 23:00:00         1         1      12.75
#
# [733 rows x 3 columns]

# %%
line_item_df[line_item_df['time']<'11:00:00']
# Out:
#        order_id        date      time          order_date  order_details_id  \
# 1029      10862  2015-07-02  10:34:34 2015-07-02 10:34:34             24700
# 4639       7521  2015-05-07  10:54:15 2015-05-07 10:54:15             17097
# 6778      16439  2015-10-04  10:54:55 2015-10-04 10:54:55             37234
# 13677     10862  2015-07-02  10:34:34 2015-07-02 10:34:34             24702
# 16267      5247  2015-03-30  10:50:46 2015-03-30 10:50:46             11943
# 16469      9991  2015-06-17  10:52:26 2015-06-17 10:52:26             22718
# 16741     16439  2015-10-04  10:54:55 2015-10-04 10:54:55             37233
# 20938      3283  2015-02-25  10:54:03 2015-02-25 10:54:03              7448
# 22088      3283  2015-02-25  10:54:03 2015-02-25 10:54:03              7449
# 22241      9991  2015-06-17  10:52:26 2015-06-17 10:52:26             22719
# 22630      5564  2015-04-04  10:43:04 2015-04-04 10:43:04             12666
# 25112      5564  2015-04-04  10:43:04 2015-04-04 10:43:04             12668
# 26216      5564  2015-04-04  10:43:04 2015-04-04 10:43:04             12667
# 28449     15092  2015-09-10  10:25:19 2015-09-10 10:25:19             34190
# 30065     19176  2015-11-24  09:52:21 2015-11-24 09:52:21             43616
# 34460     19176  2015-11-24  09:52:21 2015-11-24 09:52:21             43614
# 36639     19176  2015-11-24  09:52:21 2015-11-24 09:52:21             43615
# 37484     19176  2015-11-24  09:52:21 2015-11-24 09:52:21             43613
# 43350      5247  2015-03-30  10:50:46 2015-03-30 10:50:46             11945
# 47271      5247  2015-03-30  10:50:46 2015-03-30 10:50:46             11944
# 47893     10862  2015-07-02  10:34:34 2015-07-02 10:34:34             24701
#
#              pizza_id  quantity pizza_type_id size  price  line_cost
# 1029    classic_dlx_m         1   classic_dlx    M  16.00      16.00
# 4639       thai_ckn_l         1      thai_ckn    L  20.75      20.75
# 6778     prsc_argla_l         1    prsc_argla    L  20.75      20.75
# 13677    southw_ckn_l         1    southw_ckn    L  20.75      20.75
# 16267      cali_ckn_m         1      cali_ckn    M  16.75      16.75
# 16469      cali_ckn_m         1      cali_ckn    M  16.75      16.75
# 16741      cali_ckn_m         1      cali_ckn    M  16.75      16.75
# 20938   four_cheese_l         2   four_cheese    L  17.95      35.90
# 22088    napolitana_s         1    napolitana    S  12.00      12.00
# 22241    napolitana_s         1    napolitana    S  12.00      12.00
# 22630     calabrese_m         1     calabrese    M  16.25      16.25
# 25112    napolitana_l         1    napolitana    L  20.50      20.50
# 26216   ital_cpcllo_m         1   ital_cpcllo    M  16.00      16.00
# 28449     pepperoni_m         1     pepperoni    M  12.50      12.50
# 30065    veggie_veg_l         1    veggie_veg    L  20.25      20.25
# 34460  peppr_salami_l         1  peppr_salami    L  20.75      20.75
# 36639    the_greek_xl         1     the_greek   XL  25.50      25.50
# 37484      hawaiian_l         1      hawaiian    L  16.50      16.50
# 43350     ckn_pesto_s         1     ckn_pesto    S  12.75      12.75
# 47271   ckn_alfredo_l         1   ckn_alfredo    L  20.75      20.75
# 47893   soppressata_m         1   soppressata    M  16.50      16.50
